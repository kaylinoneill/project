# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('/Users/sadie/Desktop/stats/CountryData (1).csv')
dataset
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#         Area  Pop. Density  Coastline  Net migration  Infant mortality  \
# ...

# %%
dataset.dropna(inplace=True)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
region = dataset["Region"].values.reshape(-1, 1)
enc.fit(region)
region_OneHot = enc.transform(region)
region_one_hot = region_OneHot.toarray()
region_labels = enc.get_feature_names_out()
dataset[region_labels] = region_one_hot
dataset = dataset.drop(columns=["Region","Country"])

# %%
X = dataset.loc[:, dataset.columns != "GDP"]
y = dataset["GDP"]

# %%
X
# Out:
#      Population     Area  Pop. Density  Coastline  Net migration  \
# 0      31056997   647500          48.0       0.00          23.06
# 1       3581655    28748         124.6       1.26          -4.93
# 2      32930091  2381740          13.8       0.04          -0.39
# 6         13477      102         132.1      59.80          10.76
# 7         69108      443         156.0      34.54          -6.15
# ..          ...      ...           ...        ...            ...
# 218    25730435   912050          28.2       0.31          -0.04
# 219    84402966   329560         256.1       1.05          -0.45
# 224    21456188   527970          40.6       0.36           0.00
# 225    11502010   752614          15.3       0.00           0.00
# 226    12236805   390580          31.3       0.00           0.00
#
#      Infant mortality  Literacy  Phones  Arable  Crops  ...  \
# 0              163.07      36.0     3.2   12.13   0.22  ...
# 1               21.52      86.5    71.2   21.09   4.42  ...
# ...

# %%
y
# Out:
# 0        700.0
# 1       4500.0
# 2       6000.0
# 6       8600.0
# 7      11000.0
#         ...
# 218     4800.0
# 219     2500.0
# 224      800.0
# 225      800.0
# 226     1900.0
# Name: GDP, Length: 179, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
guess = reg.predict(X_test)

# %%
mean_squared_error(y_test,guess)
# Out:
# 19250041.221896973

# %%
reg.score(X_test, y_test)
# Out:
# 0.8385779883300541
